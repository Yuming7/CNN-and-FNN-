# %%
# !python3 -m pip install paramparse

# %%
from google.colab import drive
import os
MOUNTPOINT = "/content/gdrive"
DATADIR = os.path.join(MOUNTPOINT, "MyDrive")
drive.mount(MOUNTPOINT)
# Out:
# Mounted at /content/gdrive

# %%
# !python3 "/content/gdrive/MyDrive/Colab Notebooks/328/assignment4/A4_main.py"
# Out:
# Traceback (most recent call last):
#   File "/content/gdrive/MyDrive/Colab Notebooks/328/assignment4/A4_main.py", line 241, in <module>
#     main()
#   File "/content/gdrive/MyDrive/Colab Notebooks/328/assignment4/A4_main.py", line 137, in main
#     images = np.load(prefix + "_X.npy")
#   File "/usr/local/lib/python3.10/dist-packages/numpy/lib/npyio.py", line 405, in load
#     fid = stack.enter_context(open(os_fspath(file), "rb"))
# FileNotFoundError: [Errno 2] No such file or directory: 'valid_X.npy'
